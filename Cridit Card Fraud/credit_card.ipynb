# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('creditcard.csv')
credit_card_data.head()
# Out:
#    Unnamed: 0   Time      V1       V2      V3     V4        V5       V6  \
# 0       62176  50164 -0.2732  0.24980  1.0650  0.507  0.004597  0.76170
# 1       62177  50164  1.3160 -1.49100  0.9950 -1.315 -1.913000  0.10046
# 2       62178  50165 -1.1530  0.35280  1.3220  0.868  1.217000  2.22500
# 3       62179  50165 -1.7060 -0.03983  1.2430  1.315  0.111760 -0.35820
# 4       62180  50165  1.1370  0.13450  0.1968  0.956 -0.180300 -0.44920
#
#         V7        V8  ...      V21     V22      V23      V24     V25      V26  \
# 0  0.56900 -0.004826  ... -0.32980 -0.3242  0.03240 -0.77100 -0.1211 -0.20300
# 1 -1.54700  0.113040  ...  0.02327  0.4487 -0.14070  0.04270  0.3530 -0.05136
# 2  1.00700  0.062000  ... -0.21260  0.7007 -0.03088 -1.33400 -0.2646 -0.18030
# 3  0.05190  0.603000  ...  0.30600  0.1451 -0.07544 -0.01602  0.4292 -0.15330
# 4  0.11017 -0.016420  ... -0.10547 -0.4592 -0.05417 -0.03497  0.4802 -0.52500
#
#         V27      V28  Amount  Class
# 0  0.194100  0.15420    99.0      0
# 1  0.062130  0.03003    79.0      0
# 2  0.313700 -0.38750   100.2      0
# 3 -0.070200 -0.13780   120.0      0
# 4 -0.000886  0.01709    46.3      0
#
# [5 rows x 32 columns]

# %%
credit_card_data.info(), credit_card_data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222795 entries, 0 to 222794
# Data columns (total 32 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  222795 non-null  int64
#  1   Time        222795 non-null  int64
#  2   V1          222795 non-null  float64
#  3   V2          222795 non-null  float64
#  4   V3          222795 non-null  float64
#  5   V4          222795 non-null  float64
#  6   V5          222795 non-null  float64
#  7   V6          222795 non-null  float64
#  8   V7          222795 non-null  float64
#  9   V8          222795 non-null  float64
#  10  V9          222795 non-null  float64
#  11  V10         222795 non-null  float64
#  12  V11         222795 non-null  float64
#  13  V12         222795 non-null  float64
#  14  V13         222795 non-null  float64
#  15  V14         222795 non-null  float64
#  16  V15         222795 non-null  float64
#  17  V16         222795 non-null  float64
#  18  V17         222795 non-null  float64
#  19  V18         222795 non-null  float64
#  20  V19         222795 non-null  float64
#  21  V20         222795 non-null  float64
#  22  V21         222795 non-null  float64
#  23  V22         222795 non-null  float64
#  24  V23         222795 non-null  float64
#  25  V24         222795 non-null  float64
#  26  V25         222795 non-null  float64
#  27  V26         222795 non-null  float64
#  28  V27         222795 non-null  float64
#  29  V28         222795 non-null  float64
#  30  Amount      222795 non-null  float64
#  31  Class       222795 non-null  int64
# dtypes: float64(29), int64(3)
# memory usage: 54.4 MB
# (None,
#  Unnamed: 0    0
#  Time          0
#  V1            0
#  V2            0
#  V3            0
#  V4            0
#  V5            0
#  V6            0
#  V7            0
#  V8            0
#  V9            0
#  V10           0
#  V11           0
#  V12           0
#  V13           0
#  V14           0
#  V15           0
#  V16           0
#  V17           0
#  V18           0
#  V19           0
#  V20           0
#  V21           0
#  V22           0
#  V23           0
#  V24           0
#  V25           0
#  V26           0
#  V27           0
#  V28           0
#  Amount        0
#  Class         0
#  dtype: int64)

# %%
credit_card_data['Class'].value_counts()
# Out:
# 0    222303
# 1       492
# Name: Class, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
legit.Amount.describe(), fraud.Amount.describe()
# Out:
# (count    222303.000000
#  mean         86.231953
#  std         244.451225
#  min           0.000000
#  25%           5.000000
#  50%          20.500000
#  75%          74.940000
#  max       25700.000000
#  Name: Amount, dtype: float64,
#  count     492.000000
#  mean      122.213171
#  std       256.695232
#  min         0.000000
#  25%         1.000000
#  50%         9.250000
#  75%       105.900000
#  max      2126.000000
#  Name: Amount, dtype: float64)

# %%
credit_card_data.groupby('Class').mean()
# Out:
#           Unnamed: 0           Time        V1        V2        V3        V4  \
# Class
# 0      173502.241324  112222.031970  0.071889 -0.001645 -0.183186 -0.053691
# 1      119295.058943   80746.806911 -4.771921  3.623865 -7.033345  4.542124
#
#              V5        V6        V7        V8  ...       V20       V21  \
# Class                                          ...
# 0      0.076853 -0.027139  0.038856 -0.014987  ... -0.014020  0.006857
# 1     -3.151192 -1.397740 -5.568929  0.570853  ...  0.372342  0.713509
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.029855  0.011036 -0.001498 -0.037970 -0.005691 -0.000544 -0.001350
# 1      0.013992 -0.040305 -0.105133  0.041453  0.051648  0.170607  0.075664
#
#            Amount
# Class
# 0       86.231953
# 1      122.213171
#
# [2 rows x 31 columns]

# %%
legit_sample = legit.sample(n=492)
new_dataset = pd.concat([legit_sample, fraud], axis=0)
new_dataset.head()
# Out:
#         Unnamed: 0    Time     V1       V2      V3        V4      V5      V6  \
# 104380      166750  118287  2.060  0.22170 -1.6455  0.423000  0.4875 -0.8270
# 73016       135290   81187 -0.380  1.11500  1.2740  0.007614  0.2450 -0.5050
# 34025        96256   65688 -4.973 -7.00800  1.8070 -0.076000  5.4900 -4.4100
# 152940      215353  140033  0.267  0.12250 -0.2189 -1.962000  0.3362 -0.7690
# 75187       137462   82169 -1.519  0.03772  1.5240 -1.020000 -0.1926  0.3613
#
#             V7      V8  ...     V21     V22       V23      V24      V25  \
# 104380  0.2391 -0.2720  ... -0.3413 -0.8240  0.346400  0.60550 -0.25300
# 73016   0.6570  0.0454  ... -0.2330 -0.5460  0.007553  0.03250 -0.22220
# 34025  -4.7100  0.8535  ...  1.0860  0.9375  1.138000 -0.01588 -0.06830
# 152940  0.4250 -0.2878  ...  0.5090  1.3760 -0.223600  0.66940  0.01712
# 75187  -0.2688  0.8090  ... -0.1127 -0.3965 -0.018660 -0.71340 -0.00815
#
#             V26      V27       V28  Amount  Class
# 104380  0.16770 -0.05310 -0.027940    1.98      0
# 73016   0.10040  0.26500  0.095460    2.28      0
# 34025  -0.21940 -0.10834  0.263700   33.10      0
# 152940 -0.04108 -0.12840 -0.003227   15.00      0
# 75187   0.87650  0.14210  0.008390   68.80      0
#
# [5 rows x 32 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#           Unnamed: 0           Time        V1        V2        V3        V4  \
# Class
# 0      171689.642276  111129.849593  0.099941 -0.067242 -0.212546 -0.013339
# 1      119295.058943   80746.806911 -4.771921  3.623865 -7.033345  4.542124
#
#              V5        V6        V7        V8  ...       V20       V21  \
# Class                                          ...
# 0     -0.004227 -0.171536  0.131929 -0.056640  ... -0.057924  0.021855
# 1     -3.151192 -1.397740 -5.568929  0.570853  ...  0.372342  0.713509
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.013205  0.077119  0.007000 -0.046005  0.005418  0.044907 -0.022164
# 1      0.013992 -0.040305 -0.105133  0.041453  0.051648  0.170607  0.075664
#
#            Amount
# Class
# 0       96.197581
# 1      122.213171
#
# [2 rows x 31 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9542566709021602
# C:\Users\SSID0\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9390862944162437
